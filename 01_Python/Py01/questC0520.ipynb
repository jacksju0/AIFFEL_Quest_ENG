# %% [markdown]
# ### Q1-1 회문 판독기

# %%
print("True")
print("Flase")
# Out:
# True
# Flase

# %% [markdown]
# ### Q1-2 회문 분류기

# %%
print(" \"회문0\" ")
# Out:
#  "회문0"

# %% [markdown]
# ### Q2-1 성적 데이터화

# %%
scores=

# %% [markdown]
# ### Q2-2 성적 분석기

# %%
def score_analysis():
    ddddddd
